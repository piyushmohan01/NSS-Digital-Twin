# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv('data/2023/NSS3_2023.csv')
data.head(2)
# Out:
# C:\Users\pm_\AppData\Local\Temp\ipykernel_18508\726925041.py:1: DtypeWarning: Columns (0,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/2023/NSS3_2023.csv')
#   UKPRN Provider name      Level of study Subject code  \
# 0    UK            UK  All undergraduates  CAH01-01-01
# 1    UK            UK  All undergraduates  CAH01-01-01
#
#                            Subject  \
# 0  Medical sciences (non-specific)
# 1  Medical sciences (non-specific)
#
#                                             Question  Responses  Population  \
# 0  Q01: How good are teaching staff at explaining...      226.8       296.1
# 1  Q02: How often do teaching staff make the subj...      226.8       296.1
#
#   Suppression reason  Option 1  ...  Positivity measure (%)  Benchmark (%)  \
# 0                NaN     60.82  ...                    91.3            NaN
# 1                NaN     34.99  ...                    79.1            NaN
#
# ...

# %%
code = 'CAH02-06-07'
level = 'All undergraduates'
provider = 'Matrix College of Counselling and Psychotherapy Ltd'

data[(data['Subject code'] == code) & (data['Level of study'] == level) & (data['Provider name'] == provider)][['Responses', 'Population', 'Option 1', 'Option 2', 'Option 3', 'Option 4', 'Positivity measure (%)', 'Question', 'Publication response rate (%)']]
# Out:
#         Responses  Population  Option 1  Option 2  Option 3  Option 4  \
# 476509       29.0        30.0      24.0       5.0       0.0       0.0
# 476510       29.0        30.0      24.0       5.0       0.0       0.0
# 476511       29.0        30.0      24.0       5.0       0.0       0.0
# 476512       29.0        30.0      22.0       6.0       1.0       0.0
# 476513       29.0        30.0      20.0       9.0       0.0       0.0
# 476514       29.0        30.0      19.0      10.0       0.0       0.0
# 476515       29.0        30.0      24.0       5.0       0.0       0.0
# 476516       29.0        30.0      19.0       9.0       1.0       0.0
# 476517       29.0        30.0      21.0       8.0       0.0       0.0
# 476518       29.0        30.0      15.0      12.0       2.0       0.0
# 476519       29.0        30.0      16.0      13.0       0.0       0.0
# 476520       29.0        30.0      19.0      10.0       0.0       0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489939 entries, 0 to 489938
# Data columns (total 25 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   UKPRN                               489939 non-null  object
#  1   Provider name                       489939 non-null  object
#  2   Level of study                      489939 non-null  object
#  3   Subject code                        489939 non-null  object
#  4   Subject                             489939 non-null  object
#  5   Question                            489939 non-null  object
#  6   Responses                           489939 non-null  float64
#  7   Population                          489939 non-null  float64
#  8   Suppression reason                  348 non-null     object
#  9   Option 1                            388931 non-null  float64
#  10  Option 2                            388931 non-null  float64
# ...

# %%
data['Level of study'].value_counts()
# Out:
# Level of study
# All undergraduates                           231184
# First degree                                 209188
# Undergraduate with postgraduate component     25991
# Other undergraduate                           23576
# Name: count, dtype: int64

# %%
df = data[['UKPRN', 'Provider name', 'Level of study', 'Subject code', 'Subject', 'Question', 'Responses', 'Population',
 'Option 1', 'Option 2', 'Option 3', 'Option 4', 'Option 5', 'Positivity measure (%)',
 'Publication response rate (%)']]

# %%
df['UKPRN'].value_counts()
# Out:
# UKPRN
# UK          16434
# England     16354
# Scotland    10264
# Wales        9214
# NI           7038
#             ...
# 10007361       34
# 10013767       34
# 10001005       34
# 10008914       34
# 10000571       24
# Name: count, Length: 418, dtype: int64

# %%
df['Provider name'].value_counts()
# Out:
# Provider name
# UK                           16434
# England                      16354
# Scotland                     10264
# Wales                         9214
# Northern Ireland              7038
#                              ...
# Waverley Abbey Trust            34
# Bury College                    34
# AI Training Services Ltd.       34
# Cliff College                   34
# Shockout Arts Ltd               34
# Name: count, Length: 417, dtype: int64

# %%
df[df['UKPRN']==10007361]['Provider name'].value_counts()
# Out:
# Provider name
# Waverley Abbey Trust    34
# Name: count, dtype: int64

# %%
df.iloc[25:28]
# Out:
#    UKPRN Provider name      Level of study Subject code  \
# 25    UK            UK  All undergraduates  CAH01-01-01
# 26    UK            UK  All undergraduates  CAH01-01-01
# 27    UK            UK  All undergraduates  CAH01-01-01
#
#                             Subject  \
# 25  Medical sciences (non-specific)
# 26  Medical sciences (non-specific)
# 27  Medical sciences (non-specific)
#
#                                              Question  Responses  Population  \
# 25  Q26: How well communicated was information abo...      217.5       296.1
# 26                     Theme 1: Teaching on my course      226.8       296.1
# 27                    Theme 2: Learning opportunities      226.8       296.1
#
#     Option 1  Option 2  Option 3  Option 4  Option 5  Positivity measure (%)  \
# 25     65.48     97.98     43.99      10.0       NaN                    75.2
# 26       NaN       NaN       NaN       NaN       NaN                    86.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489939 entries, 0 to 489938
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   UKPRN                          489939 non-null  object
#  1   Provider name                  489939 non-null  object
#  2   Level of study                 489939 non-null  object
#  3   Subject code                   489939 non-null  object
#  4   Subject                        489939 non-null  object
#  5   Question                       489939 non-null  object
#  6   Responses                      489939 non-null  float64
#  7   Population                     489939 non-null  float64
#  8   Option 1                       388931 non-null  float64
#  9   Option 2                       388931 non-null  float64
#  10  Option 3                       388931 non-null  float64
#  11  Option 4                       388931 non-null  float64
# ...

# %%
theme_df = df[df['Question'].str.contains('Theme')]

# %%
theme_indices = list(theme_df.index.values) 
df = df[~df.index.isin(theme_indices)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388943 entries, 0 to 489931
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   UKPRN                          388943 non-null  object
#  1   Provider name                  388943 non-null  object
#  2   Level of study                 388943 non-null  object
#  3   Subject code                   388943 non-null  object
#  4   Subject                        388943 non-null  object
#  5   Question                       388943 non-null  object
#  6   Responses                      388943 non-null  float64
#  7   Population                     388943 non-null  float64
#  8   Option 1                       388931 non-null  float64
#  9   Option 2                       388931 non-null  float64
#  10  Option 3                       388931 non-null  float64
#  11  Option 4                       388931 non-null  float64
# ...

# %%
df.iloc[24:28]
# Out:
#    UKPRN Provider name      Level of study Subject code  \
# 24    UK            UK  All undergraduates  CAH01-01-01
# 25    UK            UK  All undergraduates  CAH01-01-01
# 33    UK            UK  All undergraduates  CAH01-01-02
# 34    UK            UK  All undergraduates  CAH01-01-02
#
#                             Subject  \
# 24  Medical sciences (non-specific)
# 25  Medical sciences (non-specific)
# 33          Medicine (non-specific)
# 34          Medicine (non-specific)
#
#                                              Question  Responses  Population  \
# 24  Q25: How well does the students' union (associ...      203.5       296.1
# 25  Q26: How well communicated was information abo...      217.5       296.1
# 33  Q01: How good are teaching staff at explaining...     6399.9      8411.8
# 34  Q02: How often do teaching staff make the subj...     6395.9      8411.8
#
#     Option 1  Option 2  Option 3  Option 4  Option 5  Positivity measure (%)  \
# ...

# %%
null_options = df[(df['Option 1'].isna())]
null_options.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 335706 to 463376
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UKPRN                          12 non-null     object
#  1   Provider name                  12 non-null     object
#  2   Level of study                 12 non-null     object
#  3   Subject code                   12 non-null     object
#  4   Subject                        12 non-null     object
#  5   Question                       12 non-null     object
#  6   Responses                      12 non-null     float64
#  7   Population                     12 non-null     float64
#  8   Option 1                       0 non-null      float64
#  9   Option 2                       0 non-null      float64
#  10  Option 3                       0 non-null      float64
#  11  Option 4                       0 non-null      float64
# ...

# %%
# df = df[~(df['Option 1'].isna())]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388943 entries, 0 to 489931
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   UKPRN                          388943 non-null  object
#  1   Provider name                  388943 non-null  object
#  2   Level of study                 388943 non-null  object
#  3   Subject code                   388943 non-null  object
#  4   Subject                        388943 non-null  object
#  5   Question                       388943 non-null  object
#  6   Responses                      388943 non-null  float64
#  7   Population                     388943 non-null  float64
#  8   Option 1                       388931 non-null  float64
#  9   Option 2                       388931 non-null  float64
#  10  Option 3                       388931 non-null  float64
#  11  Option 4                       388931 non-null  float64
# ...

# %%
df.rename(columns={'Positivity measure (%)': 'Positivity', 'Publication response rate (%)': 'Response Rate'}, inplace=True)

# %%
df[['Question', 'Positivity']].head()
# Out:
#                                             Question  Positivity
# 0  Q01: How good are teaching staff at explaining...        91.3
# 1  Q02: How often do teaching staff make the subj...        79.1
# 2  Q03: How often is the course intellectually st...        88.2
# 3  Q04: How often does your course challenge you ...        86.6
# 4  Q05: To what extent have you had the chance to...        88.5

# %%
str(df['Question'].values[0]).split(':')[0]
# Out:
# 'Q01'

# %%
df[['Question Num', 'Question']] = df['Question'].str.split(':', expand=True)

# %%
# df.drop(columns='Question', inplace=True)
df[['Question Num', 'Positivity']].head()
# Out:
#   Question Num  Positivity
# 0          Q01        91.3
# 1          Q02        79.1
# 2          Q03        88.2
# 3          Q04        86.6
# 4          Q05        88.5

# %%
df.head()
# Out:
#   UKPRN Provider name      Level of study Subject code  \
# 0    UK            UK  All undergraduates  CAH01-01-01
# 1    UK            UK  All undergraduates  CAH01-01-01
# 2    UK            UK  All undergraduates  CAH01-01-01
# 3    UK            UK  All undergraduates  CAH01-01-01
# 4    UK            UK  All undergraduates  CAH01-01-01
#
#                            Subject  \
# 0  Medical sciences (non-specific)
# 1  Medical sciences (non-specific)
# 2  Medical sciences (non-specific)
# 3  Medical sciences (non-specific)
# 4  Medical sciences (non-specific)
#
#                                             Question  Responses  Population  \
# 0   How good are teaching staff at explaining thi...      226.8       296.1
# 1   How often do teaching staff make the subject ...      226.8       296.1
# 2   How often is the course intellectually stimul...      226.5       296.1
# 3   How often does your course challenge you to a...      226.8       296.1
# ...

# %%
df['Question Num'].value_counts()
# Out:
# Question Num
# Q01    14428
# Q02    14428
# Q26    14428
# Q25    14428
# Q24    14428
# Q23    14428
# Q22    14428
# Q21    14428
# Q20    14428
# Q19    14428
# Q18    14428
# Q17    14428
# Q16    14428
# Q15    14428
# Q14    14428
# Q13    14428
# Q12    14428
# Q11    14428
# Q10    14428
# Q09    14428
# Q08    14428
# Q07    14428
# Q06    14428
# Q05    14428
# Q04    14428
# Q03    14428
# Q27    10922
# Q28     2893
# Name: count, dtype: int64

# %%
print(df[(df['Option 1'].isna())].shape)
print(df[(df['Option 2'].isna())].shape)
print(df[(df['Option 3'].isna())].shape)
print(df[(df['Option 4'].isna())].shape)
print(df[(df['Option 5'].isna())].shape)
# Out:
# (12, 16)
# (12, 16)
# (12, 16)
# (12, 16)
# (386050, 16)

# %%
df[(df['Option 1'].isna())]['UKPRN'].value_counts()
# Out:
# UKPRN
# 10007859    6
# 10007779    4
# 10007811    2
# Name: count, dtype: int64

# %%
df[(df['Option 1'].isna())]['Subject code'].value_counts()
# Out:
# Subject code
# CAH05-01-01    6
# CAH03-01-06    4
# CAH02-06-07    2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388943 entries, 0 to 489931
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UKPRN           388943 non-null  object
#  1   Provider name   388943 non-null  object
#  2   Level of study  388943 non-null  object
#  3   Subject code    388943 non-null  object
#  4   Subject         388943 non-null  object
#  5   Question        388943 non-null  object
#  6   Responses       388943 non-null  float64
#  7   Population      388943 non-null  float64
#  8   Option 1        388931 non-null  float64
#  9   Option 2        388931 non-null  float64
#  10  Option 3        388931 non-null  float64
#  11  Option 4        388931 non-null  float64
#  12  Option 5        2893 non-null    float64
#  13  Positivity      388931 non-null  float64
#  14  Response Rate   388943 non-null  float64
#  15  Question Num    388943 non-null  object
# dtypes: float64(9), object(7)
# ...

# %%
df[~((df['UKPRN'] == 10007859) & (df['Subject code'] == 'CAH05-01-01'))].shape
# Out:
# (388889, 16)

# %%
df = df[~((df['UKPRN'] == 10007859) & (df['Subject code'] == 'CAH05-01-01'))]
df = df[~((df['UKPRN'] == 10007779) & (df['Subject code'] == 'CAH03-01-06'))]
df = df[~((df['UKPRN'] == 10007811) & (df['Subject code'] == 'CAH02-06-07'))]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388781 entries, 0 to 489931
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UKPRN           388781 non-null  object
#  1   Provider name   388781 non-null  object
#  2   Level of study  388781 non-null  object
#  3   Subject code    388781 non-null  object
#  4   Subject         388781 non-null  object
#  5   Question        388781 non-null  object
#  6   Responses       388781 non-null  float64
#  7   Population      388781 non-null  float64
#  8   Option 1        388781 non-null  float64
#  9   Option 2        388781 non-null  float64
#  10  Option 3        388781 non-null  float64
#  11  Option 4        388781 non-null  float64
#  12  Option 5        2893 non-null    float64
#  13  Positivity      388781 non-null  float64
#  14  Response Rate   388781 non-null  float64
#  15  Question Num    388781 non-null  object
# dtypes: float64(9), object(7)
# ...

# %%
overall_satisfaction_rows = df[df['Question Num'] == 'Q28']
overall_satisfaction_rows.head(2)
# Out:
#       UKPRN     Provider name      Level of study Subject code  \
# 32814    NI  Northern Ireland  All undergraduates  CAH01-01-02
# 32848    NI  Northern Ireland  All undergraduates  CAH01-01-04
#
#                        Subject  \
# 32814  Medicine (non-specific)
# 32848                Dentistry
#
#                                                 Question  Responses  \
# 32814   Overall, I am satisfied with the quality of t...      233.0
# 32848   Overall, I am satisfied with the quality of t...       53.0
#
#        Population  Option 1  Option 2  Option 3  Option 4  Option 5  \
# 32814       285.0      66.0     119.0      21.0      18.0       9.0
# 32848        56.0      37.0      14.0       2.0       0.0       0.0
#
#        Positivity  Response Rate Question Num
# 32814        79.4           83.2          Q28
# 32848        96.2           94.6          Q28

# %%
not_english_prn = list(overall_satisfaction_rows['UKPRN'].unique())
not_english_df = df[(df['UKPRN'].isin(not_english_prn))]
not_english_df.head()
# Out:
#       UKPRN     Provider name      Level of study Subject code  \
# 32788    NI  Northern Ireland  All undergraduates  CAH01-01-02
# 32789    NI  Northern Ireland  All undergraduates  CAH01-01-02
# 32790    NI  Northern Ireland  All undergraduates  CAH01-01-02
# 32791    NI  Northern Ireland  All undergraduates  CAH01-01-02
# 32792    NI  Northern Ireland  All undergraduates  CAH01-01-02
#
#                        Subject  \
# 32788  Medicine (non-specific)
# 32789  Medicine (non-specific)
# 32790  Medicine (non-specific)
# 32791  Medicine (non-specific)
# 32792  Medicine (non-specific)
#
#                                                 Question  Responses  \
# 32788   How good are teaching staff at explaining thi...      236.0
# 32789   How often do teaching staff make the subject ...      236.0
# 32790   How often is the course intellectually stimul...      236.0
# 32791   How often does your course challenge you to a...      236.0
# ...

# %%
not_english_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78345 entries, 32788 to 484151
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UKPRN           78345 non-null  object
#  1   Provider name   78345 non-null  object
#  2   Level of study  78345 non-null  object
#  3   Subject code    78345 non-null  object
#  4   Subject         78345 non-null  object
#  5   Question        78345 non-null  object
#  6   Responses       78345 non-null  float64
#  7   Population      78345 non-null  float64
#  8   Option 1        78345 non-null  float64
#  9   Option 2        78345 non-null  float64
#  10  Option 3        78345 non-null  float64
#  11  Option 4        78345 non-null  float64
#  12  Option 5        2893 non-null   float64
#  13  Positivity      78345 non-null  float64
#  14  Response Rate   78345 non-null  float64
#  15  Question Num    78345 non-null  object
# dtypes: float64(9), object(7)
# ...

# %%
freedom_expression_rows = df[df['Question Num'] == 'Q27']
freedom_expression_rows.head(2)
# Out:
#          UKPRN Provider name      Level of study Subject code  \
# 16460  England       England  All undergraduates  CAH01-01-01
# 16494  England       England  All undergraduates  CAH01-01-02
#
#                                Subject  \
# 16460  Medical sciences (non-specific)
# 16494          Medicine (non-specific)
#
#                                                 Question  Responses  \
# 16460   During your studies, how free did you feel to...      184.5
# 16494   During your studies, how free did you feel to...     4897.0
#
#        Population  Option 1  Option 2  Option 3  Option 4  Option 5  \
# 16460       251.1     68.63     84.32      27.5       4.0       NaN
# 16494      6637.8   1448.40   2296.00     786.7     365.9       NaN
#
#        Positivity  Response Rate Question Num
# 16460        82.9           75.6          Q27
# 16494        76.5           75.9          Q27

# %%
english_prn = list(freedom_expression_rows['UKPRN'].unique())
english_df = df[(df['UKPRN'].isin(english_prn))]
english_df.head()
# Out:
#          UKPRN Provider name      Level of study Subject code  \
# 16434  England       England  All undergraduates  CAH01-01-01
# 16435  England       England  All undergraduates  CAH01-01-01
# 16436  England       England  All undergraduates  CAH01-01-01
# 16437  England       England  All undergraduates  CAH01-01-01
# 16438  England       England  All undergraduates  CAH01-01-01
#
#                                Subject  \
# 16434  Medical sciences (non-specific)
# 16435  Medical sciences (non-specific)
# 16436  Medical sciences (non-specific)
# 16437  Medical sciences (non-specific)
# 16438  Medical sciences (non-specific)
#
#                                                 Question  Responses  \
# 16434   How good are teaching staff at explaining thi...      189.8
# 16435   How often do teaching staff make the subject ...      189.8
# 16436   How often is the course intellectually stimul...      189.5
# 16437   How often does your course challenge you to a...      189.8
# ...

# %%
english_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295252 entries, 16434 to 489931
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UKPRN           295252 non-null  object
#  1   Provider name   295252 non-null  object
#  2   Level of study  295252 non-null  object
#  3   Subject code    295252 non-null  object
#  4   Subject         295252 non-null  object
#  5   Question        295252 non-null  object
#  6   Responses       295252 non-null  float64
#  7   Population      295252 non-null  float64
#  8   Option 1        295252 non-null  float64
#  9   Option 2        295252 non-null  float64
#  10  Option 3        295252 non-null  float64
#  11  Option 4        295252 non-null  float64
#  12  Option 5        0 non-null       float64
#  13  Positivity      295252 non-null  float64
#  14  Response Rate   295252 non-null  float64
#  15  Question Num    295252 non-null  object
# ...

# %%
english_df['Question Num'].value_counts()
# Out:
# Question Num
# Q01    10936
# Q15    10936
# Q26    10936
# Q25    10936
# Q24    10936
# Q23    10936
# Q22    10936
# Q21    10936
# Q20    10936
# Q19    10936
# Q18    10936
# Q17    10936
# Q16    10936
# Q14    10936
# Q02    10936
# Q13    10936
# Q12    10936
# Q11    10936
# Q10    10936
# Q09    10936
# Q08    10936
# Q07    10936
# Q06    10936
# Q05    10936
# Q04    10936
# Q03    10936
# Q27    10916
# Name: count, dtype: int64

# %%
english_df.iloc[25]['Question Num']
# Out:
# 'Q26'

# %%
df.iloc[25]
# Out:
# UKPRN                                                            UK
# Provider name                                                    UK
# Level of study                                   All undergraduates
# Subject code                                            CAH01-01-01
# Subject                             Medical sciences (non-specific)
# Question           How well communicated was information about y...
# Responses                                                     217.5
# Population                                                    296.1
# Option 1                                                      65.48
# Option 2                                                      97.98
# Option 3                                                      43.99
# Option 4                                                       10.0
# Option 5                                                        NaN
# Positivity                                                     75.2
# ...

# %%
# counter = 1
# for index, row in df.iterrows():
#   if index == 26*counter - 1:
#     rows_to_insert = {}
#     start = index - 25
#     end = index + 1
#     print(index+1, end=':')
#     print(counter, end=':')
#     print(df.iloc[index+1]['Question Num'])
#     if (df.iloc[index+1]['Question Num'] == 'Q27'):
#       print(df.iloc[index]['Question Num'])
#       print(df.iloc[index+1]['Question Num'])
#       print(df.iloc[index+2]['Question Num'])
#       counter += 1
#     if counter == 1000:
#       break

# %%
# df_columns = df.columns.tolist()
# only_26qn = pd.DataFrame(columns=df_columns)
# with_27qn = pd.DataFrame(columns=df_columns)
# with_28qn = pd.DataFrame(columns=df_columns)

# counter = 1
# for index, row in df.iterrows():
#   if index == 26*counter - 1:
#     rows_to_insert = {}
#     start = index - 25
#     end = index + 1
#     print(index+1, end=':')
#     print(counter)
#     if (df.iloc[index+1]['Question Num'] == 'Q01'):
#       for col in df_columns:
#         rows_to_insert[col] = list(df.iloc[start:end][col].values)
#       new_df = pd.DataFrame(rows_to_insert, columns=df_columns)
#       only_26qn = pd.concat([only_26qn, new_df], ignore_index=True)
#       counter += 1
#     elif (df.iloc[index+1]['Question Num'] == 'Q27'):
#       for col in df_columns:
#         end += 1
#         rows_to_insert[col] = list(df.iloc[start:end][col].values)
#       new_df = pd.DataFrame(rows_to_insert, columns=df_columns)
#       with_27qn = pd.concat([with_27qn, new_df], ignore_index=True)
#       counter += 1

# %%
# print(df.iloc[25]['Question Num'])
# print(df.iloc[51]['Question Num'])
# print(df.iloc[77]['Question Num'])

# %%
# only_26qn.iloc[24:28]

# %%
# only_26qn.info()

# %%
# only_26qn['Question Num'].value_counts()

# %%
# with_27qn.head()

# %%
df.shape
# Out:
# (388781, 16)

# %%
print(388781 / 26)
print(388781 % 26)
print(388781 // 26)
# Out:
# 14953.115384615385
# 3
# 14953

# %%
counter = 1
for idx in range(25, 14953, 25):
  if idx == 25*counter:
    # print(df.iloc[idx - (25 - counter + 1) : idx + counter]['Question Num'].values.tolist())
    if df.iloc[idx + counter]['Question Num'] != 'Q01':
      print(counter)
      print('---')
      print("Last Question:", df.iloc[idx + counter - 1]['Question Num'])
      print("Next Question:", df.iloc[idx + counter]['Question Num'])
      print("Position:", idx + counter)
    # print('---')
    counter += 1
    # print(counter)
  # if idx == 25:
  #   print(df.iloc[idx-25:idx+1]['Question Num'].values.tolist())
  #   print("Next Question:", df.iloc[idx+1]['Question Num'])
  # if idx == 50:
  #   print(df.iloc[idx-24:idx+2]['Question Num'].values.tolist())
  #   print("Next Question:", df.iloc[idx+2]['Question Num'])
  # if idx == 250:
  #   # print('Second')
  #   break
# Out:
# 499
# ---
# Last Question: Q26
# Next Question: Q27
# Position: 12974
# 500
# ---
# Last Question: Q25
# Next Question: Q26
# Position: 13000
# 501
# ---
# Last Question: Q24
# Next Question: Q25
# Position: 13026
# 502
# ---
# Last Question: Q23
# Next Question: Q24
# Position: 13052
# 503
# ---
# Last Question: Q22
# Next Question: Q23
# Position: 13078
# 504
# ---
# Last Question: Q21
# Next Question: Q22
# Position: 13104
# 505
# ---
# Last Question: Q20
# Next Question: Q21
# Position: 13130
# 506
# ---
# Last Question: Q19
# Next Question: Q20
# Position: 13156
# 507
# ---
# Last Question: Q18
# Next Question: Q19
# Position: 13182
# 508
# ---
# Last Question: Q17
# Next Question: Q18
# Position: 13208
# 509
# ---
# Last Question: Q16
# Next Question: Q17
# Position: 13234
# 510
# ---
# Last Question: Q15
# Next Question: Q16
# Position: 13260
# 511
# ---
# Last Question: Q14
# Next Question: Q15
# Position: 13286
# 512
# ---
# Last Question: Q13
# Next Question: Q14
# ...

# %%
df.iloc[:12974]['Question Num'].value_counts()
# Out:
# Question Num
# Q01    499
# Q02    499
# Q25    499
# Q24    499
# Q23    499
# Q22    499
# Q21    499
# Q20    499
# Q19    499
# Q18    499
# Q17    499
# Q16    499
# Q15    499
# Q14    499
# Q13    499
# Q12    499
# Q11    499
# Q10    499
# Q09    499
# Q08    499
# Q07    499
# Q06    499
# Q05    499
# Q04    499
# Q03    499
# Q26    499
# Name: count, dtype: int64

# %%
12974-27
# Out:
# 12947

# %%
df.iloc[12947]
# Out:
# UKPRN                                                            UK
# Provider name                                                    UK
# Level of study            Undergraduate with postgraduate component
# Subject code                                            CAH26-01-06
# Subject                                              Earth sciences
# Question           How well communicated was information about y...
# Responses                                                     178.2
# Population                                                    267.0
# Option 1                                                      58.14
# Option 2                                                      78.54
# Option 3                                                      28.18
# Option 4                                                       13.3
# Option 5                                                        NaN
# Positivity                                                     76.7
# ...

# %%
# df.iloc[12974-26:12975]

# %%
df.iloc[12974]
# Out:
# UKPRN                                                       England
# Provider name                                               England
# Level of study                                   All undergraduates
# Subject code                                            CAH01-01-01
# Subject                             Medical sciences (non-specific)
# Question           During your studies, how free did you feel to...
# Responses                                                     184.5
# Population                                                    251.1
# Option 1                                                      68.63
# Option 2                                                      84.32
# Option 3                                                       27.5
# Option 4                                                        4.0
# Option 5                                                        NaN
# Positivity                                                     82.9
# ...

# %%
counter = 1
for idx in range(26, 14953, 26):
  if idx == 26*counter:
    # print(df.iloc[idx - (25 - counter + 1) : idx + counter]['Question Num'].values.tolist())
    if df.iloc[idx + counter]['Question Num'] != 'Q01':
      print(counter)
      print('---')
      print("Last Question:", df.iloc[idx + counter - 1]['Question Num'])
      print("Next Question:", df.iloc[idx + counter]['Question Num'])
      print("Position:", idx + counter)
    # print('---')
    counter += 1
# Out:
# 1
# ---
# Last Question: Q01
# Next Question: Q02
# Position: 27
# 2
# ---
# Last Question: Q02
# Next Question: Q03
# Position: 54
# 3
# ---
# Last Question: Q03
# Next Question: Q04
# Position: 81
# 4
# ---
# Last Question: Q04
# Next Question: Q05
# Position: 108
# 5
# ---
# Last Question: Q05
# Next Question: Q06
# Position: 135
# 6
# ---
# Last Question: Q06
# Next Question: Q07
# Position: 162
# 7
# ---
# Last Question: Q07
# Next Question: Q08
# Position: 189
# 8
# ---
# Last Question: Q08
# Next Question: Q09
# Position: 216
# 9
# ---
# Last Question: Q09
# Next Question: Q10
# Position: 243
# 10
# ---
# Last Question: Q10
# Next Question: Q11
# Position: 270
# 11
# ---
# Last Question: Q11
# Next Question: Q12
# Position: 297
# 12
# ---
# Last Question: Q12
# Next Question: Q13
# Position: 324
# 13
# ---
# Last Question: Q13
# Next Question: Q14
# Position: 351
# 14
# ---
# Last Question: Q14
# Next Question: Q15
# Position: 378
# 15
# ---
# Last Question: Q15
# ...

# %%
df[df['Question Num'] == 'Q27'].head(2)
# Out:
#          UKPRN Provider name      Level of study Subject code  \
# 16460  England       England  All undergraduates  CAH01-01-01
# 16494  England       England  All undergraduates  CAH01-01-02
#
#                                Subject  \
# 16460  Medical sciences (non-specific)
# 16494          Medicine (non-specific)
#
#                                                 Question  Responses  \
# 16460   During your studies, how free did you feel to...      184.5
# 16494   During your studies, how free did you feel to...     4897.0
#
#        Population  Option 1  Option 2  Option 3  Option 4  Option 5  \
# 16460       251.1     68.63     84.32      27.5       4.0       NaN
# 16494      6637.8   1448.40   2296.00     786.7     365.9       NaN
#
#        Positivity  Response Rate Question Num
# 16460        82.9           75.6          Q27
# 16494        76.5           75.9          Q27

# %%
df['Question Num'].value_counts()
# Out:
# Question Num
# Q01    14422
# Q02    14422
# Q26    14422
# Q25    14422
# Q24    14422
# Q23    14422
# Q22    14422
# Q21    14422
# Q20    14422
# Q19    14422
# Q18    14422
# Q17    14422
# Q16    14422
# Q15    14422
# Q14    14422
# Q13    14422
# Q12    14422
# Q11    14422
# Q10    14422
# Q09    14422
# Q08    14422
# Q07    14422
# Q06    14422
# Q05    14422
# Q04    14422
# Q03    14422
# Q27    10916
# Q28     2893
# Name: count, dtype: int64

# %%
def get_index_col(data):
  data.index = np.arange(1, len(data) + 1)
  data['index1'] = data.index
  return data  

def get_qn27_data(data):
  q27_rows = data[data['Question Num'] == 'Q27']['index1'].values.tolist()
  with_27qn = pd.DataFrame(columns=list(data.columns))
  for i in range(len(q27_rows)):
    new_data_27 = data.iloc[q27_rows[i]-27:q27_rows[i]]
    with_27qn = pd.concat([with_27qn, new_data_27], ignore_index=True)
  return with_27qn

def get_qn28_data(data):
  q28_rows = data[data['Question Num'] == 'Q28']['index1'].values.tolist()
  with_28qn = pd.DataFrame(columns=list(data.columns))
  for i in range(len(q28_rows)):
    new_data_28 = data.iloc[q28_rows[i]-27:q28_rows[i]]
    with_28qn = pd.concat([with_28qn, new_data_28], ignore_index=True)
  return with_28qn

def generate_subsets(data):
  data = get_index_col(data)
  english_final = get_qn27_data(data)
  not_english_final = get_qn28_data(data)
  drop_rows_1 = not_english_final['index1'].values.tolist()
  drop_rows_2 = english_final['index1'].values.tolist()
  uk_final = data.copy()
  uk_final = data[~(data['index1'].isin(drop_rows_1))]
  uk_final = uk_final[~(uk_final['index1'].isin(drop_rows_2))]
  return english_final, not_english_final, uk_final

# %%
english_final, not_english_final, uk_final = generate_subsets(df)

# %%
df.index = np.arange(1, len(df) + 1)
df['index1'] = df.index
df.head()
# Out:
#   UKPRN Provider name      Level of study Subject code  \
# 1    UK            UK  All undergraduates  CAH01-01-01
# 2    UK            UK  All undergraduates  CAH01-01-01
# 3    UK            UK  All undergraduates  CAH01-01-01
# 4    UK            UK  All undergraduates  CAH01-01-01
# 5    UK            UK  All undergraduates  CAH01-01-01
#
#                            Subject  \
# 1  Medical sciences (non-specific)
# 2  Medical sciences (non-specific)
# 3  Medical sciences (non-specific)
# 4  Medical sciences (non-specific)
# 5  Medical sciences (non-specific)
#
#                                             Question  Responses  Population  \
# 1   How good are teaching staff at explaining thi...      226.8       296.1
# 2   How often do teaching staff make the subject ...      226.8       296.1
# 3   How often is the course intellectually stimul...      226.5       296.1
# 4   How often does your course challenge you to a...      226.8       296.1
# ...

# %%
q27_rows = df[df['Question Num'] == 'Q27']['index1'].values.tolist()
# df[(df['index1'].isin(q27_rows))]
with_27qn = pd.DataFrame(columns=list(df.columns))
for i in range(len(q27_rows)):
  new_df_27 = df.iloc[q27_rows[i]-27:q27_rows[i]]
  with_27qn = pd.concat([with_27qn, new_df_27], ignore_index=True)
# Out:
# C:\Users\pm_\AppData\Local\Temp\ipykernel_22356\4114474231.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   with_27qn = pd.concat([with_27qn, new_df_27], ignore_index=True)

# %%
with_27qn.shape
# Out:
# (294732, 17)

# %%
with_27qn['Question Num'].value_counts()
# Out:
# Question Num
# Q01    10916
# Q15    10916
# Q26    10916
# Q25    10916
# Q24    10916
# Q23    10916
# Q22    10916
# Q21    10916
# Q20    10916
# Q19    10916
# Q18    10916
# Q17    10916
# Q16    10916
# Q14    10916
# Q02    10916
# Q13    10916
# Q12    10916
# Q11    10916
# Q10    10916
# Q09    10916
# Q08    10916
# Q07    10916
# Q06    10916
# Q05    10916
# Q04    10916
# Q03    10916
# Q27    10916
# Name: count, dtype: int64

# %%
q28_rows = df[df['Question Num'] == 'Q28']['index1'].values.tolist()
# df[(df['index1'].isin(q28_rows))]
with_28qn = pd.DataFrame(columns=list(df.columns))
for i in range(len(q28_rows)):
  new_df_28 = df.iloc[q28_rows[i]-27:q28_rows[i]]
  with_28qn = pd.concat([with_28qn, new_df_28], ignore_index=True)
# Out:
# C:\Users\pm_\AppData\Local\Temp\ipykernel_22356\2640449595.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   with_28qn = pd.concat([with_28qn, new_df_28], ignore_index=True)

# %%
with_28qn.shape
# Out:
# (78111, 17)

# %%
len(with_28qn['Question Num'].unique())
# Out:
# 27

# %%
78111 / 27
# Out:
# 2893.0

# %%
with_28qn[with_28qn['Question Num'] == 'Q27']
# Out:
# Empty DataFrame
# Columns: [UKPRN, Provider name, Level of study, Subject code, Subject, Question, Responses, Population, Option 1, Option 2, Option 3, Option 4, Option 5, Positivity, Response Rate, Question Num, index1]
# Index: []

# %%
not_english_final = with_28qn.copy()
english_final = with_27qn.copy()
# uk_final = df[((~df['index1'].isin(q27_rows)) & ((~df['index1'].isin(q28_rows))))]

# %%
drop_rows_1 = not_english_final['index1'].values.tolist()
drop_rows_2 = english_final['index1'].values.tolist()
uk_final = df.copy()
uk_final = df[~(df['index1'].isin(drop_rows_1))]
uk_final = uk_final[~(uk_final['index1'].isin(drop_rows_2))]

# %%
print(not_english_final.shape)
print(english_final.shape)
print(uk_final.shape)
# Out:
# (78111, 17)
# (294732, 17)
# (15938, 17)

# %%
df.shape
# Out:
# (388781, 17)

# %%
uk_final[uk_final['Question Num'] == 'Q28']
# Out:
# Empty DataFrame
# Columns: [UKPRN, Provider name, Level of study, Subject code, Subject, Question, Responses, Population, Option 1, Option 2, Option 3, Option 4, Option 5, Positivity, Response Rate, Question Num, index1]
# Index: []

# %%
for val in q28_rows:
  if val == 25962:
    print('y')
# Out:
# y

# %%
not_english_final[not_english_final['index1'] == 25962]
# Out:
#    UKPRN     Provider name      Level of study Subject code  \
# 26    NI  Northern Ireland  All undergraduates  CAH01-01-02
#
#                     Subject  \
# 26  Medicine (non-specific)
#
#                                              Question  Responses  Population  \
# 26   Overall, I am satisfied with the quality of t...      233.0       285.0
#
#     Option 1  Option 2  Option 3  Option 4  Option 5  Positivity  \
# 26      66.0     119.0      21.0      18.0       9.0        79.4
#
#     Response Rate Question Num index1
# 26           83.2          Q28  25962

# %%
uk_final['Question Num'].value_counts()
# Out:
# Question Num
# Q01    613
# Q02    613
# Q25    613
# Q24    613
# Q23    613
# Q22    613
# Q21    613
# Q20    613
# Q19    613
# Q18    613
# Q17    613
# Q16    613
# Q15    613
# Q14    613
# Q13    613
# Q12    613
# Q11    613
# Q10    613
# Q09    613
# Q08    613
# Q07    613
# Q06    613
# Q05    613
# Q04    613
# Q03    613
# Q26    613
# Name: count, dtype: int64

# %%
# not_english_final.to_csv('data/2023/not_english.csv', index=False)
# english_final.to_csv('data/2023/english.csv', index=False)
# uk_final.to_csv('data/2023/uk.csv', index=False)

# %%
check = pd.read_csv('data/2023/uk.csv')
check.head()
# Out:
#   UKPRN Provider name      Level of study Subject code  \
# 0    UK            UK  All undergraduates  CAH01-01-01
# 1    UK            UK  All undergraduates  CAH01-01-01
# 2    UK            UK  All undergraduates  CAH01-01-01
# 3    UK            UK  All undergraduates  CAH01-01-01
# 4    UK            UK  All undergraduates  CAH01-01-01
#
#                            Subject  \
# 0  Medical sciences (non-specific)
# 1  Medical sciences (non-specific)
# 2  Medical sciences (non-specific)
# 3  Medical sciences (non-specific)
# 4  Medical sciences (non-specific)
#
#                                             Question  Responses  Population  \
# 0   How good are teaching staff at explaining thi...      226.8       296.1
# 1   How often do teaching staff make the subject ...      226.8       296.1
# 2   How often is the course intellectually stimul...      226.5       296.1
# 3   How often does your course challenge you to a...      226.8       296.1
# ...
