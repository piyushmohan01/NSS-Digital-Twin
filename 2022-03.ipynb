# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
level_3 = pd.read_csv('data/2022/level_3.csv')
level_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165024 entries, 0 to 165023
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 165024 non-null  int64
#  1   UKPRN                      165024 non-null  int64
#  2   Provider                   165024 non-null  object
#  3   Subject Code               165024 non-null  object
#  4   Subject                    165024 non-null  object
#  5   Level                      165024 non-null  object
#  6   Question Number            165024 non-null  object
#  7   Answered 1                 165024 non-null  object
#  8   Answered 2                 165024 non-null  object
#  9   Answered 3                 165024 non-null  object
#  10  Answered 4                 165024 non-null  object
#  11  Answered 5                 165024 non-null  object
#  12  N/A                        165024 non-null  int64
#  13  Confidence interval - min  165024 non-null  object
#  14  Actual value               165024 non-null  int64
#  15  Confidence interval - max  165024 non-null  object
#  16  Response                   165024 non-null  int64
#  17  Sample Size                165024 non-null  int64
# dtypes: int64(6), object(12)
# memory usage: 22.7+ MB

# %%
level_3.head()
# Out:
#    Unnamed: 0     UKPRN                Provider Subject Code  \
# 0           0  10007783  University of Aberdeen  CAH01-01-02
# 1           1  10007783  University of Aberdeen  CAH01-01-02
# 2           2  10007783  University of Aberdeen  CAH01-01-02
# 3           3  10007783  University of Aberdeen  CAH01-01-02
# 4           5  10007783  University of Aberdeen  CAH01-01-02
#
#                    Subject         Level Question Number Answered 1  \
# 0  Medicine (non-specific)  First degree             Q01         0%
# 1  Medicine (non-specific)  First degree             Q02         0%
# 2  Medicine (non-specific)  First degree             Q03         2%
# 3  Medicine (non-specific)  First degree             Q04         1%
# 4  Medicine (non-specific)  First degree             Q05         2%
#
#   Answered 2 Answered 3 Answered 4 Answered 5  N/A Confidence interval - min  \
# 0         4%         3%        49%        44%    0                       86%
# 1         3%         6%        53%        39%    0                       84%
# 2         0%         4%        25%        69%    0                       87%
# 3         3%         4%        37%        55%    0                       85%
# 4         2%         7%        49%        41%    1                       82%
#
#    Actual value Confidence interval - max  Response  Sample Size
# 0            93                       97%       118          162
# 1            92                       96%       118          162
# 2            94                       97%       118          162
# 3            92                       96%       118          162
# 4            90                       94%       117          162

# %%
level_3['Answered 1'] = level_3['Answered 1'].str.replace(r'%', '')
level_3['Answered 2'] = level_3['Answered 2'].str.replace(r'%', '')
level_3['Answered 3'] = level_3['Answered 3'].str.replace(r'%', '')
level_3['Answered 4'] = level_3['Answered 4'].str.replace(r'%', '')
level_3['Answered 5'] = level_3['Answered 5'].str.replace(r'%', '')

# %%
level_3['Answered 1'] = pd.to_numeric(level_3['Answered 1'])
level_3['Answered 2'] = pd.to_numeric(level_3['Answered 2'])
level_3['Answered 3'] = pd.to_numeric(level_3['Answered 3'])
level_3['Answered 4'] = pd.to_numeric(level_3['Answered 4'])
level_3['Answered 5'] = pd.to_numeric(level_3['Answered 5'])

# %%
level_3.head()
# Out:
#    Unnamed: 0     UKPRN                Provider Subject Code  \
# 0           0  10007783  University of Aberdeen  CAH01-01-02
# 1           1  10007783  University of Aberdeen  CAH01-01-02
# 2           2  10007783  University of Aberdeen  CAH01-01-02
# 3           3  10007783  University of Aberdeen  CAH01-01-02
# 4           5  10007783  University of Aberdeen  CAH01-01-02
#
#                    Subject         Level Question Number  Answered 1  \
# 0  Medicine (non-specific)  First degree             Q01           0
# 1  Medicine (non-specific)  First degree             Q02           0
# 2  Medicine (non-specific)  First degree             Q03           2
# 3  Medicine (non-specific)  First degree             Q04           1
# 4  Medicine (non-specific)  First degree             Q05           2
#
#    Answered 2  Answered 3  Answered 4  Answered 5  N/A  \
# 0           4           3          49          44    0
# 1           3           6          53          39    0
# 2           0           4          25          69    0
# 3           3           4          37          55    0
# 4           2           7          49          41    1
#
#   Confidence interval - min  Actual value Confidence interval - max  Response  \
# 0                       86%            93                       97%       118
# 1                       84%            92                       96%       118
# 2                       87%            94                       97%       118
# 3                       85%            92                       96%       118
# 4                       82%            90                       94%       117
#
#    Sample Size
# 0          162
# 1          162
# 2          162
# 3          162
# 4          162

# %%
level_3.to_csv('data/2022/level_3_all.csv')

# %%
sample = level_3[['Answered 1', 'Answered 2', 'Answered 3', 'Answered 4', 'Answered 5', 'Actual value']]
sample.to_csv('data/2022/level_3_options.csv')
sample.describe()
# Out:
#           Answered 1     Answered 2     Answered 3     Answered 4  \
# count  165024.000000  165024.000000  165024.000000  165024.000000
# mean        3.885526       7.653772      14.614153      40.926974
# std         5.387020       6.966809       9.528035      12.120066
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       2.000000       8.000000      33.000000
# 50%         2.000000       6.000000      13.000000      41.000000
# 75%         6.000000      11.000000      20.000000      48.000000
# max       100.000000      70.000000     100.000000     100.000000
#
#           Answered 5   Actual value
# count  165024.000000  165024.000000
# mean       32.955528      73.889374
# std        16.321100      15.943399
# min         0.000000       0.000000
# 25%        21.000000      65.000000
# 50%        31.000000      76.000000
# 75%        43.000000      86.000000
# max       100.000000     100.000000

# %%
sample.head()
# Out:
#    Answered 1  Answered 2  Answered 3  Answered 4  Answered 5  Actual value
# 0           0           4           3          49          44            93
# 1           0           3           6          53          39            92
# 2           2           0           4          25          69            94
# 3           1           3           4          37          55            92
# 4           2           2           7          49          41            90

# %%
sample.shape
# Out:
# (165024, 6)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165024 entries, 0 to 165023
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Answered 1    165024 non-null  int64
#  1   Answered 2    165024 non-null  int64
#  2   Answered 3    165024 non-null  int64
#  3   Answered 4    165024 non-null  int64
#  4   Answered 5    165024 non-null  int64
#  5   Actual value  165024 non-null  int64
# dtypes: int64(6)
# memory usage: 7.6 MB

# %%
data = sample.values.reshape((6112, 27, 6))

# %%
X = data[:, :26, :5].reshape(6112, 26*5)
y = data[:, 26, 5]

# %%
print(X.shape)
print(y.shape)
# Out:
# (6112, 130)
# (6112,)

# %%
from sklearn.model_selection import train_test_split

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

# model = Sequential()
# model.add(Dense(64, input_dim=26*5, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mean_squared_error')

# ---

# model = Sequential()
# # Input layer
# model.add(Dense(128, input_dim=26*5, activation='relu'))
# model.add(BatchNormalization())
# # Hidden layers
# model.add(Dense(128, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Dense(64, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Dense(32, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# # Output layer
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mean_squared_error')

# ---

# model = Sequential()
# model.add(Dense(128, input_dim=26*5, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(16, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mean_squared_error')

# ---

# model = Sequential()
# model.add(Dense(128, input_dim=26*5, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))
# optimizer = Adam(learning_rate=0.001)
# model.compile(optimizer=optimizer, loss='mean_squared_error')
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# ---

# model = Sequential()
# model.add(Dense(128, input_dim=26*5, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mean_squared_error')
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# --- 

# # # No overfitting
# model = Sequential()
# model.add(Dense(128, input_dim=26*5, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# # model.add(Dense(16, activation='relu'))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mean_squared_error')

model = Sequential()
model.add(Dense(128, input_dim=26*5, activation='relu'))
model.add(Dense(128, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
loss = model.evaluate(X_test, y_test)
print("Test Loss:", loss)

# ---

# model = Sequential()
# model.add(Dense(64, input_dim=26*5, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))
# optimizer = Adam(learning_rate=0.001)
# model.compile(optimizer=optimizer, loss='mean_squared_error')
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# ---

# model = Sequential()
# model.add(Dense(64, input_dim=26*5, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))
# optimizer = Adam(learning_rate=0.001)
# model.compile(optimizer=optimizer, loss='mean_squared_error')
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# ---

# model = Sequential()
# model.add(Dense(64, input_dim=26*5, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(16, activation='relu'))
# model.add(Dense(1))
# optimizer = Adam(learning_rate=0.01)
# model.compile(optimizer=optimizer, loss='mean_squared_error')
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# loss = model.evaluate(X_test, y_test)
# print("Test Loss:", loss)
# Out:
# Epoch 1/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4885.8799 - val_loss: 403.0123
# Epoch 2/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 260.2360 - val_loss: 1037.5713
# Epoch 3/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 140.8801 - val_loss: 261.5786
# Epoch 4/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 129.8469 - val_loss: 595.7286
# Epoch 5/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 109.7627 - val_loss: 109.6462
# Epoch 6/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.9708 - val_loss: 59.0165
# Epoch 7/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.9573 - val_loss: 96.7364
# Epoch 8/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 82.9612 - val_loss: 56.4484
# Epoch 9/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 87.8740 - val_loss: 52.1570
# Epoch 10/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 77.1991 - val_loss: 36.5087
# Epoch 11/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 78.0403 - val_loss: 37.3279
# Epoch 12/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 74.6516 - val_loss: 41.7326
# Epoch 13/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 73.9958 - val_loss: 39.2445
# Epoch 14/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 72.7624 - val_loss: 45.5017
# Epoch 15/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 71.5079 - val_loss: 66.7567
# Epoch 16/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 70.1363 - val_loss: 37.9025
# Epoch 17/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 70.1152 - val_loss: 49.0107
# Epoch 18/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 75.3727 - val_loss: 82.7313
# Epoch 19/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 73.5901 - val_loss: 53.7016
# Epoch 20/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.8966 - val_loss: 41.4298
# Epoch 21/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 67.3917 - val_loss: 38.8477
# Epoch 22/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.5754 - val_loss: 48.2534
# Epoch 23/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 65.1435 - val_loss: 115.3149
# Epoch 24/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.4630 - val_loss: 41.4010
# Epoch 25/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss:
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae_train = mean_absolute_error(y_train, predictions_train)
mse_train = mean_squared_error(y_train, predictions_train)
r2 = r2_score(y_train, predictions_train)

# Print performance metrics
print(f"Mean Absolute Error (MAE): {mae_train}")
print(f"Mean Squared Error (MSE): {mse_train}")
print(f"R² Score: {r2}")

# fig, (ax1, ax2) = plt.subplots(1, 2)


# Plot actual vs predicted values
plt.figure(figsize=(5, 4))
plt.scatter(y_train, predictions_train, alpha=0.5, label='Predicted vs Actual')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', label='Ideal Fit')
plt.xlabel('Actual Values',fontsize=15)
plt.ylabel('Predicted Values',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Train R-squared: {}'.format(round(r2, 2)), fontsize=22, weight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

# Print performance metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R² Score: {r2}")

# Plot actual vs predicted values
plt.figure(figsize=(5, 4))
plt.scatter(y_test, predictions, alpha=0.5, label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Ideal Fit')
plt.xlabel('Actual Values',fontsize=15)
plt.ylabel('Predicted Values',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Test R-squared: {}'.format(round(r2, 2)), fontsize=22, weight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# Plot residuals
residuals = y_test - predictions.flatten()
plt.figure(figsize=(8, 4))
plt.scatter(predictions, residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Values')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 4.0307738048017425
# Mean Squared Error (MSE): 26.15022431786335
# R² Score: 0.873345136642456
# Mean Absolute Error (MAE): 5.146939892117741
# Mean Squared Error (MSE): 49.62988315006574
# R² Score: 0.7677688598632812

# %%
predictions = model.predict(X_test)
predictions_train = model.predict(X_train)

r2 = r2_score(y_test, predictions)
r2_train = r2_score(y_train, predictions_train)

# Create a figure with a grid of 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # Adjust figsize as needed

# Plot 1: Actual vs Predicted for Training Data
axes[0].scatter(y_train, predictions_train, alpha=0.5, label='Predicted vs Actual')
axes[0].plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', label='Ideal Fit')
axes[0].set_xlabel('Actual Values', fontsize=15)
axes[0].set_ylabel('Predicted Values', fontsize=15)
# axes[0].set_yticks(fontsize=15)
# axes[0].set_xticks(fontsize=15)
axes[0].tick_params(axis='both', labelsize=15)
axes[0].set_title('Train R-squared: {}'.format(round(r2_train, 2)), fontsize=18, weight='bold')
axes[0].legend(fontsize=12)
axes[0].grid(True)

# Plot 2: Actual vs Predicted for Test Data
axes[1].scatter(y_test, predictions, alpha=0.5, label='Predicted vs Actual')
axes[1].plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Ideal Fit')
axes[1].set_xlabel('Actual Values', fontsize=15)
axes[1].set_ylabel('Predicted Values', fontsize=15)
# axes[1].set_yticks(fontsize=15)
# axes[1].set_xticks(fontsize=15)
axes[1].tick_params(axis='both', labelsize=15)
axes[1].set_title('Test R-squared: {}'.format(round(r2, 2)), fontsize=18, weight='bold')
axes[1].legend(fontsize=12)
axes[1].grid(True)

# Adjust the layout
plt.tight_layout()

# Show the combined plot
plt.show()
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print(history.history.keys())
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model-01 Loss Curves', fontsize=18, weight='bold')
plt.ylabel('Loss',fontsize=15)
plt.xlabel('Epoch',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# model_old = Sequential()
# model_old.add(Dense(128, input_dim=26*5, activation='relu'))
# model_old.add(Dense(64, activation='relu'))
# model_old.add(Dense(32, activation='relu'))
# # model_old.add(BatchNormalization())
# # model_old.add(Dropout(0.1))
# model_old.add(Dense(1))
# model_old.compile(optimizer='adam', loss='mean_squared_error')

model_old = Sequential()
# Input layer
model_old.add(Dense(128, input_dim=26*5, activation='relu'))
# Hidden layers
# model_old.add(Dense(128, activation='relu'))
model_old.add(Dense(64, activation='relu'))
model_old.add(Dense(64, activation='relu'))
model_old.add(Dense(32, activation='relu'))
model_old.add(Dense(16, activation='relu'))
# model_old.add(BatchNormalization())
# model_old.add(Dropout(0.2))
# Output layer
model_old.add(Dense(1))
optimizer = Adam(learning_rate=0.005)
model_old.compile(optimizer=optimizer, loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history_old = model_old.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

loss_old = model_old.evaluate(X_test, y_test)
print("Test loss_old:", loss_old)
# Out:
# c:\user_exe\00_Leeds\Dissertation\project-files\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 273.5580 - val_loss: 39.2439
# Epoch 2/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.3308 - val_loss: 36.3318
# Epoch 3/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.3903 - val_loss: 67.1993
# Epoch 4/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.9217 - val_loss: 36.0897
# Epoch 5/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.5237 - val_loss: 51.4453
# Epoch 6/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.5800 - val_loss: 35.1843
# Epoch 7/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.5871 - val_loss: 34.2035
# Epoch 8/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.8946 - val_loss: 36.0523
# Epoch 9/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9720 - val_loss: 37.5562
# Epoch 10/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.6422 - val_loss: 39.1034
# Epoch 11/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.4176 - val_loss: 34.6686
# Epoch 12/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.9408 - val_loss: 42.1123
# Epoch 13/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.3804 - val_loss: 36.8501
# Epoch 14/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.3899 - val_loss: 73.2097
# Epoch 15/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.8483 - val_loss: 36.6382
# Epoch 16/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.2575 - val_loss: 40.1038
# Epoch 17/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.9237 - val_loss: 38.4961
# Epoch 18/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.2043 - val_loss: 34.8869
# Epoch 19/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.3452 - val_loss: 34.2243
# Epoch 20/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.8834 - val_loss: 36.8178
# Epoch 21/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.0929 - val_loss: 36.2860
# Epoch 22/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.4994 - val_loss: 38.1116
# Epoch 23/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.0280 - val_loss: 36.1656
# Epoch 24/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.8650 - val_loss: 42.5099
# Epoch 25/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.8892 - val_loss: 39.2241
# Epoch 26/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.3715 - val_loss: 33.5871
# Epoch 27/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32.2248 - val_loss: 40.3287
# Epoch 28/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.7756 - val_loss: 36.2286
# Epoch 29/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.5767 - val_loss: 45.9988
# Epoch 30/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.4702 - val_loss: 34.2055
# Epoch 31/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.0688 - val_loss: 37.6194
# Epoch 32/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.6405 - val_loss: 36.1363
# Epoch 33/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.2997 - val_loss: 35.2021
# Epoch 34/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.1068 - val_loss: 38.0172
# Epoch 35/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.2282 - val_loss: 34.0355
# Epoch 36/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.7897 - val_loss: 36.7092
# Epoch 37/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.6132 - val_loss: 41.5289
# Epoch 38/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.1831 - val_loss: 43.9860
# Epoch 39/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.0177 - val_loss: 39.6831
# Epoch 40/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.3514 - val_loss: 45.0713
# Epoch 41/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae_train = mean_absolute_error(y_train, predictions_train)
mse_train = mean_squared_error(y_train, predictions_train)
r2 = r2_score(y_train, predictions_train)

# Print performance metrics
print(f"Mean Absolute Error (MAE): {mae_train}")
print(f"Mean Squared Error (MSE): {mse_train}")
print(f"R² Score: {r2}")

# fig, (ax1, ax2) = plt.subplots(1, 2)


# Plot actual vs predicted values
plt.figure(figsize=(5, 4))
plt.scatter(y_train, predictions_train, alpha=0.5, label='Predicted vs Actual')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', label='Ideal Fit')
plt.xlabel('Actual Values',fontsize=15)
plt.ylabel('Predicted Values',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Train R-squared: {}'.format(round(r2, 2)), fontsize=22, weight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

# Print performance metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R² Score: {r2}")

# Plot actual vs predicted values
plt.figure(figsize=(5, 4))
plt.scatter(y_test, predictions, alpha=0.5, label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Ideal Fit')
plt.xlabel('Actual Values',fontsize=15)
plt.ylabel('Predicted Values',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Test R-squared: {}'.format(round(r2, 2)), fontsize=22, weight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# Plot residuals
residuals = y_test - predictions.flatten()
plt.figure(figsize=(8, 4))
plt.scatter(predictions, residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Values')
plt.grid(True)
plt.show()
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Absolute Error (MAE): 3.7972351650831815
# Mean Squared Error (MSE): 24.56886761420465
# R² Score: 0.8810042142868042
# Mean Absolute Error (MAE): 4.730447314161798
# Mean Squared Error (MSE): 43.12092301470914
# R² Score: 0.7982259392738342

# %%
sample_input = X_test[21].reshape(1, -1)
predicted_output = model_old.predict(sample_input)
print("Predicted Output:", predicted_output[0][0])
print("Actual Output:", y_test[21])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted Output: 53.819103
# Actual Output: 68

# %%
sample_input = X_test[14].reshape(1, -1)
predicted_output = model.predict(sample_input)
print("Sample Input:", X_test[14])
print("Input Shape:", X_test[14].shape)
print("Predicted Output:", predicted_output[0][0])
print("Actual Output:", y_test[14])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Sample Input: [ 0  4  7 76 14  1  9 24 50 15  1  2  6 43 48  1  7 12 42 39  2  4 14 47
#  33  0  7 12 48 32  3 10 23 31 33  3 14 20 45 18  5 10 17 49 19 25 20 19
#  26 10  4 19 27 37 12  1  5 13 52 28  2  8 22 49 19  2 18 17 38 25  5 23
#  15 43 14  2 10 13 45 30  3 10 17 47 22  3  7 14 40 35  1  5 10 38 46  4
#   5 10 41 40  7 15 25 35 19  1  1  5 42 51  1  3  8 40 48 11 20 19 35 15
#  14 23 30 24  9  3  5 28 42 22]
# Input Shape: (130,)
# Predicted Output: 74.639885
# Actual Output: 75

# %%
print(history.history.keys())
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model-02 Loss Curves', fontsize=18, weight='bold')
plt.ylabel('Loss',fontsize=15)
plt.xlabel('Epoch',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
print(history_old.history.keys())
# summarize history for loss
plt.plot(history_old.history['loss'])
plt.plot(history_old.history['val_loss'])
plt.title('Model-02 Loss Curves', fontsize=18, weight='bold')
plt.ylabel('loss',fontsize=15)
plt.xlabel('epoch',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(['train', 'validation'], loc='upper left', fontsize=12)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
sns.heatmap(sample.corr(), annot=True)
# Out:
# <Axes: >

# %%
level_3.describe()
# Out:
#           Unnamed: 0         UKPRN     Answered 1     Answered 2  \
# count  165024.000000  1.650240e+05  165024.000000  165024.000000
# mean   106959.055556  1.005160e+07       3.885526       7.653772
# std     61753.571933  1.993303e+06       5.387020       6.966809
# min         0.000000  1.000006e+07       0.000000       0.000000
# 25%     53479.750000  1.000534e+07       0.000000       2.000000
# 50%    106959.500000  1.000716e+07       2.000000       6.000000
# 75%    160439.250000  1.000780e+07       6.000000      11.000000
# max    213919.000000  1.000000e+08     100.000000      70.000000
#
#           Answered 3     Answered 4     Answered 5            N/A  \
# count  165024.000000  165024.000000  165024.000000  165024.000000
# mean       14.614153      40.926974      32.955528       0.456085
# std         9.528035      12.120066      16.321100       2.310798
# min         0.000000       0.000000       0.000000       0.000000
# 25%         8.000000      33.000000      21.000000       0.000000
# 50%        13.000000      41.000000      31.000000       0.000000
# 75%        20.000000      48.000000      43.000000       0.000000
# max       100.000000     100.000000     100.000000     384.000000
#
#         Actual value       Response    Sample Size
# count  165024.000000  165024.000000  165024.000000
# mean       73.889374      58.495649      84.737402
# std        15.943399      78.937530     128.960855
# min         0.000000       4.000000      10.000000
# 25%        65.000000      19.000000      25.000000
# 50%        76.000000      35.000000      49.000000
# 75%        86.000000      71.000000     100.000000
# max       100.000000    2636.000000    4904.000000

# %%
level_3['Completion rate'] = level_3['Response'] / level_3['Sample Size']
level_3.head()
# Out:
#    Unnamed: 0     UKPRN                Provider Subject Code  \
# 0           0  10007783  University of Aberdeen  CAH01-01-02
# 1           1  10007783  University of Aberdeen  CAH01-01-02
# 2           2  10007783  University of Aberdeen  CAH01-01-02
# 3           3  10007783  University of Aberdeen  CAH01-01-02
# 4           5  10007783  University of Aberdeen  CAH01-01-02
#
#                    Subject         Level Question Number  Answered 1  \
# 0  Medicine (non-specific)  First degree             Q01           0
# 1  Medicine (non-specific)  First degree             Q02           0
# 2  Medicine (non-specific)  First degree             Q03           2
# 3  Medicine (non-specific)  First degree             Q04           1
# 4  Medicine (non-specific)  First degree             Q05           2
#
#    Answered 2  Answered 3  Answered 4  Answered 5  N/A  \
# 0           4           3          49          44    0
# 1           3           6          53          39    0
# 2           0           4          25          69    0
# 3           3           4          37          55    0
# 4           2           7          49          41    1
#
#   Confidence interval - min  Actual value Confidence interval - max  Response  \
# 0                       86%            93                       97%       118
# 1                       84%            92                       96%       118
# 2                       87%            94                       97%       118
# 3                       85%            92                       96%       118
# 4                       82%            90                       94%       117
#
#    Sample Size  Completion rate
# 0          162         0.728395
# 1          162         0.728395
# 2          162         0.728395
# 3          162         0.728395
# 4          162         0.722222

# %%
print(level_3['Provider'].unique().shape)
print(level_3['Subject'].unique().shape)
# Out:
# (422,)
# (161,)

# %%
sample.size
# Out:
# 990144
